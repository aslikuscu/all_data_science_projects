# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv(r"C:\Users\asli_\PYTHON_PROJECTS\big_project\BankChurners.csv")

# %%
dataset.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
dataset.shape
# Out:
# (10127, 23)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
dataset.describe().round(1)
# Out:
#          CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count      10127.0       10127.0          10127.0         10127.0
# mean   739177606.3          46.3              2.3            35.9
# std     36903783.5           8.0              1.3             8.0
# min    708082083.0          26.0              0.0            13.0
# 25%    713036770.5          41.0              1.0            31.0
# 50%    717926358.0          46.0              2.0            36.0
# 75%    773143533.0          52.0              3.0            40.0
# max    828343083.0          73.0              5.0            56.0
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                   10127.0                 10127.0
# mean                        3.8                     2.3
# std                         1.6                     1.0
# min                         1.0                     0.0
# 25%                         3.0                     2.0
# ...

# %%
dataset.nunique()
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                            2
# Customer_Age                                                                                                                             45
# Gender                                                                                                                                    2
# Dependent_count                                                                                                                           6
# Education_Level                                                                                                                           7
# Marital_Status                                                                                                                            4
# ...

# %%
dataset['Card_Category'].nunique()
# Out:
# 4

# %%
dataset['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
dataset[dataset['Customer_Age']>40]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 5      713061558  Existing Customer            44      M                2
# 6      810347208  Existing Customer            51      M                4
# ...          ...                ...           ...    ...              ...
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
dataset.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
dataset.notnull().sum()
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                        10127
# Customer_Age                                                                                                                          10127
# Gender                                                                                                                                10127
# Dependent_count                                                                                                                       10127
# Education_Level                                                                                                                       10127
# Marital_Status                                                                                                                        10127
# ...

# %%
dataset['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: count, dtype: int64

# %%
# Ortalama müşteri yaşı ve gelir kategorisine göre

dataset.groupby('Income_Category')['Customer_Age'].mean()
# Out:
# Income_Category
# $120K +           47.603851
# $40K - $60K       46.087151
# $60K - $80K       45.968616
# $80K - $120K      46.428013
# Less than $40K    46.297950
# Unknown           46.274281
# Name: Customer_Age, dtype: float64

# %%
# Kart kategorisine göre toplam işlem miktarı

dataset.groupby('Income_Category')['Total_Trans_Amt'].sum()
# Out:
# Income_Category
# $120K +            3292923
# $40K - $60K        7886058
# $60K - $80K        6239899
# $80K - $120K       6881344
# Less than $40K    15538139
# Unknown            4761819
# Name: Total_Trans_Amt, dtype: int64

# %%
# Gelir kategorisi "Less than $40K" olan ve kredi limitleri 5000'in üstünde olan müşteriler


high_income_and_high_card_limit = dataset[(dataset['Income_Category'] >= '$40K') & (dataset['Credit_Limit'] > 5000)]
high_income_and_high_card_limit
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 7      818906208  Existing Customer            32      M                0
# 8      710930508  Existing Customer            37      M                3
# 9      719661558  Existing Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10119  716893683  Attrited Customer            55      F                3
# 10120  710841183  Existing Customer            54      M                1
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Cinsiyete göre kredi limiti istatistikleri

dataset.groupby('Gender')['Credit_Limit'].describe()
# Out:
#          count          mean           std     min     25%     50%      75%  \
# Gender
# F       5358.0   5023.854274   5251.881090  1438.3  2160.0  3048.0   5638.5
# M       4769.0  12685.674963  10647.936985  1438.3  3805.0  8902.0  19040.0
#
#             max
# Gender
# F       34516.0
# M       34516.0

# %%
# 40 yaşın üstünde olup, evli olan ve kredi limiti 10000'in üzerinde olan müşteriler

specific_customers = dataset[(dataset['Customer_Age'] > 40) & (dataset['Credit_Limit'] > 10000) & (dataset['Marital_Status'] == 'Married')]

specific_customers
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 6      810347208  Existing Customer            51      M                4
# 17     753327333  Existing Customer            41      M                3
# 19     709327383  Existing Customer            45      F                2
# 24     789124683  Existing Customer            54      M                2
# ...          ...                ...           ...    ...              ...
# 10086  824150733  Existing Customer            43      M                2
# 10095  789023508  Existing Customer            46      M                3
# 10103  717185658  Attrited Customer            51      M                1
# 10117  712503408  Existing Customer            57      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Eğitim seviyesine göre kredi limiti ve ortalama kredi kullanımı


dataset.groupby('Education_Level').agg({'Credit_Limit' : 'mean', 'Avg_Utilization_Ratio' : 'mean'})
# Out:
#                  Credit_Limit  Avg_Utilization_Ratio
# Education_Level
# College           8684.536130               0.265399
# Doctorate         8413.258980               0.260619
# Graduate          8566.100927               0.277719
# High School       8605.823547               0.278275
# Post-Graduate     8862.560465               0.280572
# Uneducated        8899.509011               0.271590
# Unknown           8491.798947               0.276469

# %%
pd.crosstab(dataset['Marital_Status'], dataset['Attrition_Flag'])
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer
# Marital_Status
# Divorced                      121                627
# Married                       709               3978
# Single                        668               3275
# Unknown                       129                620

# %%
education_levels = dataset['Education_Level'].value_counts()
education_levels
# Out:
# Education_Level
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: count, dtype: int64

# %%
descriptive_stats = dataset.groupby('Income_Category').agg({
    'Credit_Limit': ['mean', 'std'],
    'Total_Trans_Amt': ['mean', 'std']
})
descriptive_stats
# Out:
#                  Credit_Limit               Total_Trans_Amt
#                          mean           std            mean          std
# Income_Category
# $120K +          19717.322558  12064.309210     4529.467675  3816.054540
# $40K - $60K       5462.259832   4557.471801     4405.618994  3382.499980
# $60K - $80K      10758.772967   8862.475017     4450.712553  3789.005119
# $80K - $120K     15809.890945  11259.665550     4482.960261  3788.213644
# Less than $40K    3754.404521   2759.888288     4363.420107  3097.398449
# Unknown           9516.582464   8677.921738     4282.211331  2922.695013
